# %%
import pandas as pd

# %% [markdown]
# ### kospi 차이 큰 일자 뽑기

# %%
sb = pd.read_csv('/content/drive/MyDrive/자료/2023BigContest/Data/SB_kospi.csv')

# %%
sb.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close  Volume
# 0  2018-01-02  367000.0  391000.0  367000.0  389500.0   389500.0  409343
# 1  2018-01-03  391000.0  395500.0  385000.0  391000.0   391000.0  270751
# 2  2018-01-04  391500.0  393000.0  381500.0  383000.0   383000.0  229586
# 3  2018-01-05  383000.0  391000.0  380000.0  390000.0   390000.0  150573
# 4  2018-01-08  393000.0  400000.0  385000.0  399500.0   399500.0  371714

# %%
sb['diff'] = sb.Close.diff()

# %%
sb['diff_abs'] = sb['diff'].abs()

# %%
SB_big_date = list(sb.sort_values('diff_abs', ascending=False).head(10)['Date'])

# %%
SB_big_date
# Out:
# ['2018-05-02',
#  '2018-11-12',
#  '2021-05-14',
#  '2020-04-10',
#  '2021-05-17',
#  '2022-01-27',
#  '2020-03-20',
#  '2021-10-05',
#  '2020-10-29',
#  '2018-12-11']

# %%
sb.sort_values('diff_abs', ascending=False).head(10)
# Out:
#             Date      Open      High       Low     Close  Adj Close   Volume  \
# 82    2018-05-02  410500.0  445500.0  391500.0  404000.0   404000.0  2332526
# 210   2018-11-12  341000.0  343500.0  281000.0  285500.0   285500.0  1504675
# 828   2021-05-14  901000.0  948000.0  866000.0  948000.0   948000.0  1010588
# 559   2020-04-10  500000.0  603000.0  494500.0  559000.0   559000.0  3037570
# 829   2021-05-17  930000.0  932000.0  874000.0  874000.0   874000.0   546343
# 1003  2022-01-27  757000.0  758000.0  712000.0  712000.0   712000.0   165806
# 544   2020-03-20  383500.0  451000.0  371500.0  430000.0   430000.0   586738
# 924   2021-10-05  849000.0  859000.0  807000.0  812000.0   812000.0   170809
# 694   2020-10-29  630000.0  701000.0  630000.0  697000.0   697000.0   301106
# 231   2018-12-11  393000.0  420000.0  385000.0  394000.0   394000.0  1393121
#
#          diff  diff_abs
# 82   -84000.0   84000.0
# 210  -82500.0   82500.0
# 828   82000.0   82000.0
# ...

# %%
sb_news = pd.read_csv('/content/drive/MyDrive/자료/2023BigContest/Data/SB_20180101-20221231.csv')

# %%
sb_news[sb_news['일자']==20200320]
# Out:
#        Unnamed: 0        뉴스 식별자        일자    언론사                          기고자  \
# 28351       14000  2.100601e+06  20200320   한국경제                          NaN
# 28352       14001  2.100101e+06  20200320   매일경제                          김시균
# 28353       14002  2.100601e+06  20200320   한국경제  차은지(chachacha@hankyung.com)
# 28354       14003  2.100801e+06  20200320  아시아경제                          박지환
# 28355       14004  2.100851e+06  20200320   아주경제                          안준호
# 28356       14005  2.100101e+06  20200320   매일경제                          고득관
# 28357       14006  2.100311e+06  20200320   서울경제                       박경훈 기자
# 28358       14007  2.100201e+06  20200320  머니투데이                       김도윤|기자
# 28359       14008  2.100311e+06  20200320   서울경제                          뉴스봇
# 28360       14009  2.100311e+06  20200320   서울경제                       박경훈 기자
# 28361       14010  2.100101e+06  20200320   매일경제                          고득관
# ...
